# %% [markdown]
# <a href="https://colab.research.google.com/github/koreanlch/sudoku/blob/main/sudoku.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#스도쿠 풀이 프로그램 저장용
####################################### 스도쿠 현모습을 출력하는 print_now함수 ####
def print_now():
  show = '\n'
  Count = 0
  for t in range(len(cell)):
    if type(cell[t][3]) ==type([1,2,3]):
      show += "0 "
      if (t+1)%9 == 0 :
        show += '\n'
    else:
      Count+=1
      show += str(cell[t][3])+' '
      if (t+1)%9 == 0 :
        show += '\n'
  print(str(show)+"\n"+str(Count)+"칸이 채워졌습니다."+"\n")
####################################### 개발과정에서 코드작동 확인용 Check함수 ####
def Check():
  check = '\n'
  for k in range(len(cell)):
    check += str(cell[k][3])+' '
    if (k+1)%9 == 0 :
      check += '\n'
  print(check)
####################################### a행의 모든 빈 셀의 리스트에서 b를 삭제 ####
def write(a,b,c):
    cell[(a-1)*9+b-1][3] = c
    print("\n"+str(a)+"행 "+str(b)+"열의 값을 "+str(c)+"로 채웠습니다")
    print_now()
####################################### a행의 모든 빈 셀의 리스트에서 b를 삭제 ####
def del_row(a,b):
  if a==0 and b== 0:
    for x in range(81):
      if type(cell[x][3]) == type(1):
        for y in range(81):
          if cell[y][0] == cell[x][0]:
            if type(cell[y][3]) == type([1,2,3]):
              if cell[x][3] in cell[y][3]:
                cell[y][3].remove(cell[x][3])

  else:
    for v in range(81):
      if cell[v][0] == a :
        if type(cell[v][3]) == type([1,2,3]):
          if b in cell[v][3]:
            cell[v][3].remove(b)
            global change
            change +=1
####################################### a열의 모든 빈 셀의 리스트에서 b를 삭제 ####
def del_col(a,b):
  if a==0 and b== 0:
    for x in range(81):
      if type(cell[x][3]) == type(1):
        for y in range(81):
          if cell[y][1] == cell[x][1]:
            if type(cell[y][3]) == type([1,2,3]):
              if cell[x][3] in cell[y][3]:
                cell[y][3].remove(cell[x][3])

  else:
    for v in range(81):
      if cell[v][1] == a :
        if type(cell[v][3]) == type([1,2,3]):
          if b in cell[v][3]:
            cell[v][3].remove(b)

            global change
            change += 1
####################################### a칸의 모든 빈 셀의 리스트에서 b를 삭제 ####
def del_sub(a,b):
  if a==0 and b== 0:
    for x in range(81):
      if type(cell[x][3]) == type(1):
        for y in range(81):
          if cell[y][2] == cell[x][2]:
            if type(cell[y][3]) == type([1,2,3]):
              if cell[x][3] in cell[y][3]:
                cell[y][3].remove(cell[x][3])


  else:
    for v in range(81):
      if cell[v][2] == a :
        if type(cell[v][3]) == type([1,2,3]):
          if b in cell[v][3]:
            cell[v][3].remove(b)
            global change
            change += 1
####################################### 값을 확정하고, 나머지 모든 셀에서 삭제 ####
def correct():
  for w in range(81):
    if type(cell[w][3]) == type([1,2,3]):
      if len(cell[w][3]) == 1 :
        cell[w][3] = cell[w][3][0]
        rn=cell[w][0]+1
        cn=cell[w][1]+1
        v =cell[w][3]
        print(str(rn)+"행 "+str(cn)+"열 셀의 값을 "+str(v)+ "로 확정했습니다.")
        print_now()
        global change
        change += 1
        del_row(cell[w][0],cell[w][3])
        del_col(cell[w][1],cell[w][3])
        del_sub(cell[w][2],cell[w][3])

####################################### 각 행에서 유일값이 든 셀의 나머지 삭제 ####
def only_row():
  for k in range(9):
    only=[]
    only_num = 0
    for j in range(81):
      if cell[j][0] == k:
        if type(cell[j][3])==type([1,2,3]):
          only+=(cell[j][3])
    if only==[]:
        pass
    else:
        for i in range(9):
            if only.count(i+1)==1:
                only_num = i+1
                break
        if only_num ==0:
            break
    for l in range(81):
        if cell[l][0]==k:
          if type(cell[l][3])==type([1,2]):
            if only_num in cell[l][3]:
              cell[l][3] = only_num
              rn=cell[l][0]+1
              cn=cell[l][1]+1
              v =cell[l][3]
              print("\nEasy 수준의 발견입니다."+"\n"+ str(rn)+"행에는 "+str(v)+"가 들어갈 수 있는 곳이 "+str(cn)+ "열 밖에 없습니다.")
              print(str(rn)+"행 "+str(cn)+"열 셀의 값을 "+str(v)+ "로 확정했습니다.")
              del_row(cell[l][0],cell[l][3])
              del_col(cell[l][1],cell[l][3])
              del_sub(cell[l][2],cell[l][3])
              global change
              change +=1
              print_now()
              break
    if change!=1:
      return
####################################### 각 열에서 유일값이 든 셀의 나머지 삭제 ####
def only_col():
  for k in range(9):
    only=[]
    only_num = 0
    for j in range(81):
      if cell[j][1] == k:
        if type(cell[j][3])==type([1,2,3]):
          only+=(cell[j][3])
    if only==[]:
        pass
    else:
        for i in range(9):
            if only.count(i+1)==1:
                only_num = i+1
                break
        if only_num ==0:
            break
    for l in range(81):
        if cell[l][1]==k:
          if type(cell[l][3])==type([1,2]):
            if only_num in cell[l][3]:
              cell[l][3] = only_num
              rn=cell[l][0]+1
              cn=cell[l][1]+1
              v =cell[l][3]
              print("\nEasy 수준의 발견입니다."+"\n"+ str(cn)+"열에는 "+str(v)+"가 들어갈 수 있는 곳이 "+str(rn)+ "행 밖에 없습니다.")
              print(str(rn)+"행 "+str(cn)+"열 셀의 값을 "+str(v)+ "로 확정했습니다.")
              del_row(cell[l][0],cell[l][3])
              del_col(cell[l][1],cell[l][3])
              del_sub(cell[l][2],cell[l][3])
              global change
              change +=1
              print_now()
              break
    if change!=1:
      return
####################################### 각 칸에서 유일값이 든 셀의 나머지 삭제 ####
def only_sub():
  for k in range(9):
    only=[]
    only_num = 0
    for j in range(81):
      if cell[j][2] == k:
        if type(cell[j][3])==type([1,2,3]):
          only+=(cell[j][3])
    if only==[]:
        pass
    else:
        for i in range(9):
            if only.count(i+1)==1:
                only_num = i+1
                break
        if only_num ==0:
            break

    for l in range(81):
        if cell[l][2]==k:
          if type(cell[l][3])==type([1,2]):
            if only_num in cell[l][3]:
              cell[l][3] = only_num
              rn=cell[l][0]+1
              cn=cell[l][1]+1
              sn=cell[l][2]+1
              v =cell[l][3]
              print("\nEasy 수준의 발견입니다."+"\n"+ str(sn)+"번째 블럭에는 "+str(v)+"가 들어갈 수 있는 곳이 "+str(rn)+"행 "+str(cn)+ "열 밖에 없습니다.")
              print(str(rn)+"행 "+str(cn)+"열 셀의 값을 "+str(v)+ "로 확정했습니다.")
              del_row(cell[l][0],cell[l][3])
              del_col(cell[l][1],cell[l][3])
              del_sub(cell[l][2],cell[l][3])
              global change
              change +=1
              print_now()
              break
    if change!=1:
      return
####################################### 행,열,칸의 유일값 함수 및 correct 실행 ####
def Easy():
    global change
    only_row()
    correct()
    if change !=1:
        return
    only_col()
    correct()
    if change !=1:
        return
    only_sub()
    correct()

####################################### 행에서 a가 한 칸에 있을때 칸에서 a삭제 ####
def must_row():
  for i in range(9):
      for j in range(9):
          must=[]
          for k in range(81):
            if cell[k][0] == i:
                if type(cell[k][3]) == type([1,2]):
                    if (j+1) in cell[k][3]:
                        if cell[k][2] in must:
                            pass
                        else:
                            must.append(cell[k][2])
          if len(must) == 1:
              rem = 0
              for l in range(81):
                if cell[l][2] == must[0]:
                  if cell[l][0] != i:
                    if type(cell[l][3]) == type([1,2,3]):
                      if (j+1) in cell[l][3]:
                        cell[l][3].remove((j+1))
                        rem += 1
              if rem >= 1:
                  print("\nNormal 수준의 발견입니다.")
                  print(str(i+1)+"번째 행과 "+str(must[0]+1)+"번째 블럭에 집중해보세요.")
                  pr1 = str(i+1)+"번째 행에는 "+str(j+1)+"이 필요하고 "+str(j+1)+"는 "+str(must[0]+1)+"번째 블럭에 있어야 하므로\n"
                  pr2 = "이 블럭의 "+str(i+1)+"번째 행에 속하지 않는 모든 셀의 후보에서 "+str(j+1)+"를 제외할 수 있습니다\n"
                  print(pr1+pr2)
                  global change
                  change +=1
                  correct()
                  return
####################################### 열에서 a가 한 칸에 있을때 칸에서 a삭제 ####
def must_col():
  for i in range(9):
      for j in range(9):
          must=[]
          for k in range(81):
            if cell[k][1] == i:
                if type(cell[k][3]) == type([1,2]):
                    if (j+1) in cell[k][3]:
                        if cell[k][2] in must:
                            pass
                        else:
                            must.append(cell[k][2])
          if len(must) == 1:
              rem = 0
              for l in range(81):
                if cell[l][2] == must[0]:
                  if cell[l][1] != i:
                    if type(cell[l][3]) == type([1,2,3]):
                      if (j+1) in cell[l][3]:
                        cell[l][3].remove((j+1))
                        rem+=1
              if rem>=1:
                print("\nNormal 수준의 발견입니다.")
                print(str(i+1)+"번째 열과 "+str(must[0]+1)+"번째 블럭에 집중해보세요.")
                pr1 = str(i+1)+"번째 열에는 "+str(j+1)+"이 필요하고 "+str(j+1)+"는 "+str(must[0]+1)+"번째 블럭에 있어야 하므로\n"
                pr2 = "이 블럭의 "+str(i+1)+"번째 열에 속하지 않는 모든 셀의 후보에서 "+str(j+1)+"를 제외할 수 있습니다\n"
                print(pr1+pr2)
                global change
                change +=1
                correct()
                return
####################################### 칸에서 a가 한 행에 있을때 행에서 a삭제 ####
def must_subr():
  for i in range(9):
      for j in range(9):
          must=[]
          for k in range(81):
            if cell[k][2] == i:
                if type(cell[k][3]) == type([1,2]):
                    if (j+1) in cell[k][3]:
                        if cell[k][0] in must:
                            pass
                        else:
                            must.append(cell[k][0])
          if len(must) == 1:
              rem = 0
              for l in range(81):
                if cell[l][0] == must[0]:
                  if cell[l][2] != i:
                    if type(cell[l][3]) == type([1,2,3]):
                      if (j+1) in cell[l][3]:
                        cell[l][3].remove((j+1))
                        rem +=1
              if rem>=1:
                print("\nNormal 수준의 발견입니다.")
                print(str(i+1)+"번째 블럭과 "+str(must[0]+1)+"번째 행에 집중해보세요.")
                pr1 = str(i+1)+"번째 블럭에는 "+str(j+1)+"이 필요하고 "+str(j+1)+"는 "+str(must[0]+1)+"번째 행에 있어야 하므로\n"
                pr2 = "이 행의 "+str(i+1)+"번째 블럭에 속하지 않는 모든 셀의 후보에서 "+str(j+1)+"를 제외할 수 있습니다\n"
                print(pr1+pr2)
                global change
                change +=1
                correct()
                return
####################################### 칸에서 a가 한 열에 있을때 열에서 a삭제 ####
def must_subc():
  for i in range(9):
      for j in range(9):
          must=[]
          for k in range(81):
            if cell[k][2] == i:
                if type(cell[k][3]) == type([1,2]):
                    if (j+1) in cell[k][3]:
                        if cell[k][1] in must:
                            pass
                        else:
                            must.append(cell[k][1])
          if len(must) == 1:
              rem=0
              for l in range(81):
                if cell[l][1] == must[0]:
                  if cell[l][2] != i:
                    if type(cell[l][3]) == type([1,2,3]):
                      if (j+1) in cell[l][3]:
                        cell[l][3].remove((j+1))
                        rem +=1
              if rem >= 1:
                print("\nNormal 수준의 발견입니다.")
                print(str(i+1)+"번째 블럭과 "+str(must[0]+1)+"번째 열에 집중해보세요.")
                pr1 = str(i+1)+"번째 블럭에는 "+str(j+1)+"이 필요하고 "+str(j+1)+"는 "+str(must[0]+1)+"번째 열에 있어야 하므로\n"
                pr2 = "이 열의 "+str(i+1)+"번째 블럭에 속하지 않는 모든 셀의 후보에서 "+str(j+1)+"를 제외할 수 있습니다\n"
                print(pr1+pr2)
                global change
                change +=1
                correct()
                return
####################################### 행,열,칸의 must함수 4개와 correct 실행 ####
def Normal():
    global change
    must_row()
    if change !=1:
        return
    must_col()
    if change !=1:
        return
    must_subr()
    if change !=1:
        return
    must_subc()

####################################### 2개의 칸이 연계된 형태의 must_subr함수 ####
def must_2subr():
    pass
####################################### 2개의 칸이 연계된 형태의 must_subc함수 ####
def must_2subc():
    pass
####################################### must2 함수와 correct를 실행하는 Tricky ####
def Tricky():
    must_2subr()
    must_2subc()
    correct()

####################################### 스도쿠를 입력받아 형태를 가공하는 과정 ####
print("스도쿠를 빈칸은 0으로 간주하여 한 줄에 숫자 9개씩 9줄로 입력해주세요")
cell=[]
for i in range(9):                        # 다음을 9번 반복
  cells = []                              # 빈 리스트 cells 생성
  row= input()                            # 첫째 줄의 숫자 9개를 9자리 문자열로 받아 row로 저장
  for j in range(9):                      # 다음을 9번 반복
    cells.append(row[j])                  # row의 각 자리 숫자를 순서대로 cells 리스트에 추가
    cell.append([])                       # cell에 빈 리스트를 만들어, 각 리스트에 row,col,sub,value의 값을 입력한다
    cell[j+i*9].append(i)                 # [0]=row ,[1]=col, [2]=sub, [3]=value
    cell[j+i*9].append(j)
    cell[j+i*9].append((i//3)*3+((j//3)))
    cell[j+i*9].append(int(row[j]))
for z in range(81) :
  if cell[z][3] == 0:
    cell[z][3] = [1,2,3,4,5,6,7,8,9]
print_now()                              #########나중에 지우기
####################################### 정의한 함수를 이용, 스도쿠를 직접 풀이 ####
global change
change = 0
del_col(0,0)
del_row(0,0)
del_sub(0,0)
while change !=1:
  change =1
  correct()
  complete =0
  for i in range(81):
      if type(cell[i][3])==type(1):
          complete +=1
  if complete == 81 :
      print("스도쿠를 모두 풀었습니다.")
      break
  else:
    if change ==1:
      Command = input("힌트를 보시겠습니까? (Y/N)\n")
      if Command == "N":
        a,b,c = map(int,input("\n채우고자 하는 셀의 위치와 채우고자 하는 값을 띄어쓰기로 입력해주세요\n(a행 b열에 c를 넣고 싶다면 \"a b c\" 입력)").split())
        write(a,b,c)
        change+=1
      elif Command == "Y":
        Easy()
        if change == 1:
          Normal()
          if change == 1:
              print("아직 더 이상의 힌트를 제공할 능력이 되지 않습니다 꾸준히 업데이트 하겠습니다.")

####### 예 제 ######
#  지금 사용하는 방법
#  주어진 문제에서 빈칸의 모든 후보수를 입력한다.
#  correct = 후보수가 1개만 남은 수를 확정하고, 다시 row,col,sub 실행
#  매 순간 유저가 푼 셀의 숫자를 입력할 것인지, 힌트를 볼 것인지 선
#  Easy : 행, 열, 칸에서 유일한 후보수를 찾아 나머지 수 제거 + correct
#  Normal : x가 특정 a 안에서 한 b 에만 있을 때, 전체 b 중 a를 제외한 부분에서 x 삭제 +correct
#  Tricky : Normal의 경우가 조합된 경우
#  advanced
#  Hard
#  Challenging
#  Extreme
# Out:
# 스도쿠를 띄어쓰기 없이 빈칸은 0으로 간주하여 한 줄에 숫자 9개씩 9줄로 입력해주세요
